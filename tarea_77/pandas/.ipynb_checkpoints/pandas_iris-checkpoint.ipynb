# %% [markdown]
# ------------------------------------------------------------------------------------------------------<br>
# <h3 style="background:#87a1c2; color:#ffffff; padding:20px; border-radius:5px;">✍ IRIS DATASET - PANDAS</h3><br>
# ------------------------------------------------------------------------------------------------------<br>

# %% [markdown]
# <b>BREVE EXPLICACIÓN DEL DATASET:</b><br>
# <img src="img/iris.png">
# <img src="img/iris2.png">

# %%
import pandas as pd
data = pd.read_csv("dataset/00_iris.csv") # Leer el CSV

# %%
data.head(3) # Listar cabecera
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
data.sample(10) # Listar Aleatorio
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 128           6.1          3.0           4.9          1.8   virginica
# 51            7.0          3.2           4.7          1.4  versicolor
# 109           6.7          2.5           5.8          1.8   virginica
# 140           6.9          3.1           5.4          2.1   virginica
# 135           6.1          2.6           5.6          1.4   virginica
# 28            5.2          3.5           1.5          0.2      setosa
# 52            6.4          3.2           4.5          1.5  versicolor
# 117           6.5          3.0           5.5          1.8   virginica
# 17            5.4          3.9           1.3          0.4      setosa
# 84            6.0          2.7           5.1          1.6  versicolor

# %%
data.columns # Listar columnas
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data.shape # Número de filas y columnas
# Out:
# (151, 5)

# %%
print(data) # Escribir el dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             5.1          3.5           1.4          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7          3.0           5.2          2.3  virginica
# 147           6.3          2.5           5.0          1.9  virginica
# 148           6.5          3.0           5.2          2.0  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9          3.0           5.1          1.8  virginica
#
# [151 rows x 5 columns]

# %%
'''data [inicio: fin]
inicio es inclusivo mientras que fin es exclusivo
print(data[10:21])
imprimirá las filas del 10 al 20.
también se puede guardar en una variable para su uso posterior en el análisis
'''

rebanado_data=data[10:25]
print(rebanado_data)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 10           4.9          3.1           1.5          0.1  setosa
# 11           5.4          3.7           1.5          0.2  setosa
# 12           4.8          3.4           1.6          0.2  setosa
# 13           4.8          3.0           1.4          0.1  setosa
# 14           4.3          3.0           1.1          0.1  setosa
# 15           5.8          4.0           1.2          0.2  setosa
# 16           5.7          4.4           1.5          0.4  setosa
# 17           5.4          3.9           1.3          0.4  setosa
# 18           5.1          3.5           1.4          0.3  setosa
# 19           5.7          3.8           1.7          0.3  setosa
# 20           5.1          3.8           1.5          0.3  setosa
#     sepal_length  sepal_width  petal_length  petal_width species
# 10           4.9          3.1           1.5          0.1  setosa
# ...

# %%
''' 
aquí en el caso del conjunto de datos Iris
lo guardaremos en otra variable llamada "datos_específicos"
data[["column_name1","column_name2","column_name3"]]
'''

specifico_data=data[["sepal_length","species"]]

#Ahora imprimiremos las primeras 10 filas del marco de datos específico_datos.
print(specifico_data.head(10))
# Out:
#    sepal_length species
# 0           5.1  setosa
# 1           4.9  setosa
# 2           4.7  setosa
# 3           5.1  setosa
# 4           4.6  setosa
# 5           5.0  setosa
# 6           5.4  setosa
# 7           4.6  setosa
# 8           5.0  setosa
# 9           4.4  setosa

# %%
# Mostrará registros solo con la especie "Iris-setosa".
data.loc[data["species"] == "setosa"]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            5.1          3.5           1.4          0.2  setosa
# 4            4.6          3.1           1.5          0.2  setosa
# 5            5.0          3.6           1.4          0.2  setosa
# 6            5.4          3.9           1.7          0.4  setosa
# 7            4.6          3.4           1.4          0.3  setosa
# 8            5.0          3.4           1.5          0.2  setosa
# 9            4.4          2.9           1.4          0.2  setosa
# 10           4.9          3.1           1.5          0.1  setosa
# 11           5.4          3.7           1.5          0.2  setosa
# 12           4.8          3.4           1.6          0.2  setosa
# ...

# %%
''' En este conjunto de datos trabajaremos en la columna Especies, 
contará el número de veces que se ha repetido una especie en particular.'''
data["species"].value_counts()
# Out:
# setosa        51
# virginica     50
# versicolor    50
# Name: species, dtype: int64

# %%
sum_data = data["sepal_length"].sum() #suma
mean_data = data["sepal_length"].mean() #media
median_data = data["sepal_length"].median() #mediana
print("Suma:",sum_data, "\nMedia:", mean_data, "\nMediana:",median_data)
# Out:
# Suma: 881.5999999999999
# Media: 5.838410596026492
# Mediana: 5.8

# %%
min_data=data["sepal_length"].min() #mínimo
max_data=data["sepal_length"].max() #máximo
print("Mínimo:",min_data, "\nMáxim0:", max_data)
# Out:
# Mínimo: 4.3
# Máxim0: 7.9

# %%
''' Aquí imprimiremos solo las 10 filas superiores del conjunto de datos,
si desea ver el resultado de todo el conjunto de datos, elimine
.head (10) del siguiente código'''
data.head(10).style.highlight_max(color='yellow', axis=0) #filas
# Out:
# <style  type="text/css" >
# #T_83646c18_bf96_11eb_9e3d_fc7774a19833row6_col0,#T_83646c18_bf96_11eb_9e3d_fc7774a19833row6_col1,#T_83646c18_bf96_11eb_9e3d_fc7774a19833row6_col2,#T_83646c18_bf96_11eb_9e3d_fc7774a19833row6_col3{
#             background-color:  yellow;
#         }</style><table id="T_83646c18_bf96_11eb_9e3d_fc7774a19833" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal_length</th>        <th class="col_heading level0 col1" >sepal_width</th>        <th class="col_heading level0 col2" >petal_length</th>        <th class="col_heading level0 col3" >petal_width</th>        <th class="col_heading level0 col4" >species</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_83646c18_bf96_11eb_9e3d_fc7774a19833level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_83646c18_bf96_11eb_9e3d_fc7774a19833row0_col0" class="data row0 col0" >5.100000</td>
# ...

# %%
data.head(10).style.highlight_max(color='lightgreen', axis=1) #columnas
# Out:
# <style  type="text/css" >
# #T_83694973_bf96_11eb_94f8_fc7774a19833row0_col0,#T_83694973_bf96_11eb_94f8_fc7774a19833row1_col0,#T_83694973_bf96_11eb_94f8_fc7774a19833row2_col0,#T_83694973_bf96_11eb_94f8_fc7774a19833row3_col0,#T_83694973_bf96_11eb_94f8_fc7774a19833row4_col0,#T_83694973_bf96_11eb_94f8_fc7774a19833row5_col0,#T_83694973_bf96_11eb_94f8_fc7774a19833row6_col0,#T_83694973_bf96_11eb_94f8_fc7774a19833row7_col0,#T_83694973_bf96_11eb_94f8_fc7774a19833row8_col0,#T_83694973_bf96_11eb_94f8_fc7774a19833row9_col0{
#             background-color:  lightgreen;
# ...

# %%
data.head(10).style.highlight_max(color='lightgreen', axis=None) #todo el dataframe
# Out:
# <style  type="text/css" >
# #T_836d3f13_bf96_11eb_8721_fc7774a19833row6_col0{
#             background-color:  lightgreen;
#         }</style><table id="T_836d3f13_bf96_11eb_8721_fc7774a19833" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal_length</th>        <th class="col_heading level0 col1" >sepal_width</th>        <th class="col_heading level0 col2" >petal_length</th>        <th class="col_heading level0 col3" >petal_width</th>        <th class="col_heading level0 col4" >species</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_836d3f13_bf96_11eb_8721_fc7774a19833level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_836d3f13_bf96_11eb_8721_fc7774a19833row0_col0" class="data row0 col0" >5.100000</td>
#                         <td id="T_836d3f13_bf96_11eb_8721_fc7774a19833row0_col1" class="data row0 col1" >3.500000</td>
# ...

# %%
data.head(10).style.highlight_min(color='#cd4f39', axis=None) #mínimo todo el dataframe, color en hexadecimal
# Out:
# <style  type="text/css" >
# #T_8371a822_bf96_11eb_9de2_fc7774a19833row0_col3,#T_8371a822_bf96_11eb_9de2_fc7774a19833row1_col3,#T_8371a822_bf96_11eb_9de2_fc7774a19833row2_col3,#T_8371a822_bf96_11eb_9de2_fc7774a19833row3_col3,#T_8371a822_bf96_11eb_9de2_fc7774a19833row4_col3,#T_8371a822_bf96_11eb_9de2_fc7774a19833row5_col3,#T_8371a822_bf96_11eb_9de2_fc7774a19833row8_col3,#T_8371a822_bf96_11eb_9de2_fc7774a19833row9_col3{
#             background-color:  #cd4f39;
#         }</style><table id="T_8371a822_bf96_11eb_9de2_fc7774a19833" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal_length</th>        <th class="col_heading level0 col1" >sepal_width</th>        <th class="col_heading level0 col2" >petal_length</th>        <th class="col_heading level0 col3" >petal_width</th>        <th class="col_heading level0 col4" >species</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
data.isnull() #si faltan datos, se mostrará Verdadero o Falso.
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
# 150         False        False         False        False    False
#
# [151 rows x 5 columns]

# %%
data.isnull().sum() # suma de missings
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
missing_values_count = data.isnull().sum()
missing_values_count[0:10] #para las primeras 10 filas
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
total_cells = np.product(data.shape) #Contamos el total de datos
print ("Celdas total:", total_cells)
total_missing = missing_values_count.sum()
print ("Missing total: ", total_missing)
print ("% de missings: ", total_missing/total_cells*100)
# Out:
# Celdas total: 755
# Missing total:  0
# % de missings:  0.0

# %%
#renombrar columnas
newcols={
"sepal_length":"sepallength",
"sepal_width":"sepalwidth"}
data.rename(columns=newcols,inplace=True)
print(data.head())
# Out:
#    sepallength  sepalwidth  petal_length  petal_width species
# 0          5.1         3.5           1.4          0.2  setosa
# 1          4.9         3.0           1.4          0.2  setosa
# 2          4.7         3.2           1.3          0.2  setosa
# 3          5.1         3.5           1.4          0.2  setosa
# 4          4.6         3.1           1.5          0.2  setosa

# %%
data['species']=data['species'].replace(['setosa','versicolor','virginica'],[0,1,2])
print(data.head())
# Out:
#    sepallength  sepalwidth  petal_length  petal_width  species
# 0          5.1         3.5           1.4          0.2        0
# 1          4.9         3.0           1.4          0.2        0
# 2          4.7         3.2           1.3          0.2        0
# 3          5.1         3.5           1.4          0.2        0
# 4          4.6         3.1           1.5          0.2        0

# %%
data.to_csv(r'dataset\00_iris_manipulado.csv', index = False)

# %% [markdown]
# <h3>👏👏👏 You guys rock !!!</h3>
